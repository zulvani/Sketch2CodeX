# %% [markdown]
# # Layout Manager Evaluation
# Evaluates layout manager grid-based algorithm.
#
# **Metrics:**
# - **TED Similarity**
# - **Entropy Weight Method (EWM) Similarity**
#
# **Directory structure expected:**
# ```
# root/
#   wireframe_name/
#     test-*-result-s2c.json                        ← Ground Truth DSL for our proposed classification model
#     test-*-result-sdn.json                        ← Ground Truth DSL for Sketch-DeepNet classification model
#     test-*-result-yolov11.json                        ← Ground Truth DSL for YOLOv11 classification model
# ```

# %%
# Step 1: Set parameters
ROOT       = "/Users/aguszulvani/goota/httpd_doc_root/generated-wireframe"
OUTPUT_CSV = "/Users/aguszulvani/goota/httpd_doc_root/generated-wireframe/layout_manager_evaluation_result.csv"
SCRIPT     = "evaluate_layout_manager.py"

# Step 2: Run
# %run $SCRIPT $ROOT --output $OUTPUT_CSV
# Out:
# Evaluating: /Users/aguszulvani/goota/httpd_doc_root/generated-wireframe
# ...
# [SKIP] RESULT: ground truth not found (RESULT.json)
# [SKIP] __pycache__: ground truth not found (__pycache__.json)
# [OK] test-desktop-1-btpns-cms-mapping-wisma        GT= 56  GEN= 56  matched= 55  F1=0.9821  Jaccard=0.9649
# [OK] test-desktop-1-hand-agus-btpns-cms-mapping-wisma GT= 56  GEN= 56  matched= 55  F1=0.9821  Jaccard=0.9649
# [OK] test-desktop-1-hand-dimas-btpns-cms-mapping-wisma GT= 47  GEN= 47  matched= 45  F1=0.9574  Jaccard=0.9184
# [OK] test-desktop-1-hand-fadli-btpns-cms-mapping   GT= 47  GEN= 47  matched= 45  F1=0.9574  Jaccard=0.9184
# [OK] test-desktop-1-hand-pazrin-btpns-cms-mapping-wisma GT= 51  GEN= 51  matched= 45  F1=0.8824  Jaccard=0.7895
# [OK] test-desktop-1-hand-tia-btpns-cms-mapping-wisma GT= 56  GEN= 56  matched= 53  F1=0.9464  Jaccard=0.8983
# [OK] test-desktop-10-browse-product                GT= 58  GEN= 69  matched= 32  F1=0.5039  Jaccard=0.3368
# ...
