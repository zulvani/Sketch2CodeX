# %% [markdown]
# # Layout Manager Evaluation
# Evaluates layout manager grid-based algorithm.
#
# **Metrics:**
# - **TED Similarity**
# - **Entropy Weight Method (EWM) Similarity**
#
# **Directory structure expected:**
# ```
# root/
#   wireframe_name/
#     test-*-result-s2c.json                        ← Ground Truth DSL for our proposed classification model
#     test-*-result-sdn.json                        ← Ground Truth DSL for Sketch-DeepNet classification model
#     test-*-result-yolov11.json                        ← Ground Truth DSL for YOLOv11 classification model
# ```

# %%
# !pip install seaborn
# !pip install zss

# %%
# Step 1: Calculate TED vs EWM using F1 and Jaccard Scoring
ROOT       = "/Users/aguszulvani/goota/httpd_doc_root/generated-wireframe"
OUTPUT     = "/Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/ted_vs_ewm_evaluation_result.csv"
SCRIPT     = "ted_ewm.py"

# Step 2: Run
# %run $SCRIPT $ROOT --output $OUTPUT

# %%
# Step 2: Visualize the results using charts
ROOT       = "/Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results"
CSV_FILE = f"{ROOT}/ted_vs_ewm_evaluation_result.csv"
OUTPUT_CHART_DIR = f"{ROOT}/"
SCRIPT     = "visualize_results.py"

# Step 2: Run
# %run $SCRIPT $CSV_FILE --output $OUTPUT_CHART_DIR
# Out:
# Loaded 150 wireframes from /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/ted_vs_ewm_evaluation_result.csv
# Output directory: /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results
#
# 1/5  Heatmap ...
#   Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/01_heatmap.png
# 2/5  Radar ...
#   Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/02_radar.png
# 3/5  Scatter ...
#   Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/03_scatter_ted_vs_ewm.png
# 4/5  Bar EWM vs Equal-W ...
#   Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/04_bar_ewm_vs_equal.png
# 5/5  Histogram ...
#   Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE/layout-manager/evaluation_results/05_histogram.png
#
# ...
