# %% [markdown]
# # Code Generator Evaluation
# Evaluates generated code across 3 classification methods × 3 frameworks
#
# **Metrics:**
# - **CCR** — Component Coverage Rate (vs Ground Truth DSL)
# - **LSR** — Layout Structure Rate (F1 + Jaccard)
#
# **Directory structure expected:**
# ```
# root/
#   wireframe_name/
#     wireframe_name.json                        ← Ground Truth DSL
#     vue/
#       wireframe_name-s2c.vue                   ← Proposed model
#       wireframe_name-sdn.vue                   ← SketchDeepNet
#       wireframe_name-yolov11.vue               ← YOLOv11
#     react/
#       wireframe_name-s2c.tsx
#       wireframe_name-sdn.tsx
#       wireframe_name-yolov11.tsx
#     flutter/
#       wireframe_name-s2c.dart
#       wireframe_name-sdn.dart
#       wireframe_name-yolov11.dart
# ```

# %%
# Step 1: Set parameters
ROOT       = "/Users/aguszulvani/LEARNING-ML/DSL"
OUTPUT_CSV = f"{ROOT}/FINAL_RESULT/CODE-GENERATED-EVALUATION/results_codegen_v1.csv"
CHART_DIR  = f"{ROOT}/FINAL_RESULT/CODE-GENERATED-EVALUATION"
SCRIPT     = f"{ROOT}/FINAL_RESULT/CODE-GENERATED-EVALUATION/evaluate_codegen_v1.py"

# Step 2: Run
# %run $SCRIPT $ROOT --output $OUTPUT_CSV --chart $CHART_DIR
# Out:
# ...
# SUMMARY — per classification method
#
# Method                 CCR   CCR_F1   LSR_F1   LSR_Jac
# ──────────────────────────────────────────────────────
# proposed           0.8694  0.8694  0.8150   0.7216
# sketch deep net    0.8710  0.8710  0.8135   0.7201
# yolov11            0.8279  0.8279  0.8145   0.7212
# ──────────────────────────────────────────────────────
# OVERALL    0.8561  0.8561  0.8144   0.7210
#
#   Wireframes : 150
#   Stacks     : vue, react, flutter
#   Total files: 1350
#
#   CCR  — Component Coverage Rate (vs Ground Truth)
#          avg 10.3 / 12.0 components matched per wireframe
#
#   LSR  — Layout Structure Rate (F1 + Jaccard)
#          avg 21.2 / 27.2 layout tokens matched per wireframe
#
#
# [CSV] Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE-GENERATED-EVALUATION/results_codegen_v1.csv
# [Chart] Saved → /Users/aguszulvani/LEARNING-ML/DSL/FINAL_RESULT/CODE-GENERATED-EVALUATION/codegen_evaluation_v1.png
